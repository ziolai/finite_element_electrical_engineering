# %% [markdown]
# # EE4375: Fifth Lab Session: Geometry and Mesh Generation using GMSH

# %% [markdown]
# The **goals** of this fifth lab session of the [EE4375 Course](https://github.com/ziolai/finite_element_electrical_engineering/tree/main) is to explore the use of the [GMSH](https://gmsh.info) package for geometry and mesh generation.
#
# For the **geometry generation**, GMSH can be employed using one of three methods that are described next:
# 1. The first method is to build the geometry in GMSH from the ground up using the GMSH primitives for points, lines, surfaces and volumes. This allows to generate 1D, 2D or 3D geometries. This way of working provides detailed control over the geometry definition. It allows to automate the geometry creation through scripting. Two examples are given later in this notebook.  A possible disadvantage is the large overhead for complex geometries.
# 2. The second method is create the geometry in dedicated CAD modeling tools, to save the geometry to file and to import the geometry into the GMSH graphical user interface. Examples of public domain CAD modeling tools include [Blender](https://www.blender.org), [FreeCAD](https://www.freecad.org) and [Salome](https://www.salome-platform.org).
# 3. The third method is to use GMSH as a plugin for CAD tools as e.g. a [plugin for Blender](https://github.com/blender-for-science/blendmsh), [plugin for FreeCAD](https://wiki.freecad.org/Macro_GMSH) or [plugin for SALOME](https://docs.salome-platform.org/latest/gui/GMSHPLUGIN/index.html).
#
# For the unstructured **mesh generation** in 2D and 3D, GMSH provides various algorithms that are described in the GMSH manual at [GMSH Mesh Module](https://gmsh.info/doc/texinfo/gmsh.html#Choosing-the-right-unstructured-algorithm). In 2D, a mesh consisting of triangles is called a [triangulation](https://en.wikipedia.org/wiki/Triangulation_(geometry)). Often a variant of the [Delaunay algorithm](https://en.wikipedia.org/wiki/Delaunay_triangulation) is used to construct these triangular meshes. We refer to [Mesh Generation](https://en.wikipedia.org/wiki/Mesh_generation) for more information on mesh generation.

# %% [markdown]
# ## Import Packages

# %%
try
    using Gmsh: Gmsh, gmsh
catch
    using gmsh
end 

using GR 
using LinearAlgebra
using SparseArrays

using Test 

using Plots

# %% [markdown]
# ## Section 1: Unit Square Geometry

# %% [markdown]
# The code that follows performs the followings steps. First the <b>geometry</b> on the unit square geometry is defined, then the geometry model is synchronized, then physical groups are added and finally the <b>mesh</b> is generated.
#
# <b>Geometry Definition</b>
#
# First the <b>geometry</b> is generated in the following five steps:
# 1. four corner points of the square are defined. The points are defined by their $(x,y,z)$-coordinates. For two-dimensional geometries, the $z$-coordinate set to zero. The points are labeled as 1 through 4. See docs of function addPoint() for more information;
# 2. four lines are defined as the edges of the square are defined by connecting previously defined points. Edges are formed by connecting points pairwise. The lines are given a start and end point. The lines are thus oriented. GMSH distinguishes between tags given to points (entities of dimensions zero), tags given to lines (entities of dimension one), tags given to surfaces (entities of dimension two) and tags given to volumes (entities of dimension three). GMSH uses the convention (dim,tag) to distinguish various entities. The edges are labeled as 1 through 4. See docs of function addLine() for more information;
# 3. the boundary of the square is defined by a loop connecting the four edges. The orientation of the edges given an orientation to the loop. The loop is oriented such that an imaginary observer walking on the loop finds the domain on his left-hand side. The loop is labeled as 1. See docs of function addCurveLoop() for more information;
# 4. the surface of the square is defined by the loop. It is on this square that the mesh generation will take place. This square is labeled as 1. See docs of function addPlaneSurface() for more information;
#
# Next the CAD model is synchronized and physical groups are added to the model.
#
# <b>Mesh Generation</b>
#
# Next the <b>mesh</b> on the geometry is defined by mesh generation. The mesh is generated by first meshing the four edges of the square. The mesh is subsequently propagated towards the interior of the square. The mesh density is controlled by the parameter lc.
#
# The mesh is optionally written to an oputput file and visualized using the GUI.
#
# <b>Exercises </b>:
# 1. change the coordinate of one of the four points of the square and regenerate the mesh;
# 2. change the mesh density by changing the value of the parameter lc and regenerate the mesh. Apply different mesh density on one or more point or edges of the square;
# 3. extend the code to the generation of a mesh on a pentagon;
# 4. extend the code to the generation of a mesh on an L-shaped domain;
# 5. extend the code to the generation of a mesh on a square with an inner square removed (thus practising the orientation of the loops);
# 6. extend the code to the generation of a mesh on a domain consisting of an inner and outer square (thus practising the assignment of subdomain labels);
# 7. extend the code to the generation of a mesh consisting of quadrilaterals (using <i>gmsh.model.mesh.setRecombine(2, surf)</i> );
# 8. extend the code to the generation of a mesh consisting of trianglels or quadrilaterals with second order Lagrangian basis functions (using <i>gmsh.model.mesh.setOrder(elementOrder)</i>);
# 9. extract information the element area (one-half the determinant of the Jacobian) from GMSH using the function <i>mesh.getJacobians</i> as demonstrated in the tutorial [x6.jl](https://gitlab.onelab.info/gmsh/gmsh/blob/gmsh_4_15_0/tutorials/julia/x6.jl);
# 10. adapt the loop over the elements of the surface (see below) by a loop over the elements on the boundary only;
# 11. generate the geometry of the inductor (see below) using OpenCasCade;

# %%
#?gmsh.option.setNumber

# %%
#..1/8: initialize gmsh 
should_finalize = Gmsh.initialize()

#..2/8: set GMSH global options 
gmsh.option.setNumber("General.Terminal",1) # make more verbose 
gmsh.option.setNumber("Mesh.Algorithm",6) # choose mesh algorithm 
gmsh.model.add("square")

#..3/8: generate geometry 
#..set mesh density parameter 
lc = .1
#..define four points via (x,y,z) coordinates 
p1 = gmsh.model.geo.addPoint(0, 0, 0, lc, 1)
p2 = gmsh.model.geo.addPoint(1., 0,  0, lc, 2)
p3 = gmsh.model.geo.addPoint(1., 1., 0, lc, 3)
p4 = gmsh.model.geo.addPoint(0, 1., 0, lc, 4)
#..define four edges by connecting point labels pairwise  
l1 = gmsh.model.geo.addLine(1, 2, 1)
l2 = gmsh.model.geo.addLine(2, 3, 2)
l3 = gmsh.model.geo.addLine(3, 4, 3)
l4 = gmsh.model.geo.addLine(4, 1, 4)
#..define curved loop by connecting four edge labels  
loop = gmsh.model.geo.addCurveLoop([1, 2, 3, 4], 1)
#..define surface by curved loop 
surf = gmsh.model.geo.addPlaneSurface([1], 1)

#..4/8: synchronize the CAD model 
gmsh.model.geo.synchronize()

#..5/8: assign physical groups
gmsh.model.addPhysicalGroup(1, [l1], -1, "bottom")
gmsh.model.addPhysicalGroup(1, [l2], -1, "right")
gmsh.model.addPhysicalGroup(1, [l3], -1, "top")
gmsh.model.addPhysicalGroup(1, [l4], -1, "left")
gmsh.model.addPhysicalGroup(2, [surf], -1, "omega")

#..6/8: generate two-dimensional mesh 
gmsh.model.mesh.generate(2)

#..7/8: write mesh to mesh and visualize the mesh  
#..if true, write mesh to file for further processing
gmsh.option.setNumber("Mesh.Format", 16)
if (true) gmsh.write("data/square.msh") end 
#..if true, visualize mesh through the GUI 
if (false) gmsh.fltk.run() end 

#..8/8: finalize gmsh 
should_finalize && Gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 30%] Meshing curve 2 (Line)
# Info    : [ 60%] Meshing curve 3 (Line)
# Info    : [ 80%] Meshing curve 4 (Line)
# Info    : Done meshing 1D (Wall 0.000626667s, CPU 0.0005s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00604983s, CPU 0.003811s)
# Info    : 142 nodes 286 elements
# Info    : Writing 'data/square.msh'...
# Info    : Done writing 'data/square.msh'
# false

# %% [markdown]
# ## Section 2: Read Mesh from File and Retrieve Information
#
# ### Section 1.2: Retrieve Element Information using the Function getElements()
#
# We wish to retrieve the nodes of a element with a given tag (or identifyer) in the mesh. We do so by looping over the elements obtained after calling the function <i>getElements</i>.
#
# Note that:
# 1. given a 1D mesh, getElement(0) retrieves 0D elements (boundary points) and getElement(1) retrieves 1D elements. The connectivity information is retrieved as well;
# 1. given a 2D mesh, getElement(0) retrieves 0D elements (boundary points), getElement(1) retrieves 1D elements (boundary intervals) and getElement(2) retrieves 2D elements;
# 1. given a 3D mesh, getElement(0) retrieves 0D elements (boundary points), getElement(1) retrieves 1D elements (boundary intervals) and getElement(2) retrieves 2D elements (boundary triangles) and getElement(3) to retrieve 3D elements;

# %%
#..1/5: Finalize gmsh
should_finalize = Gmsh.initialize()

#..2/5: Read mesh from file
gmsh.open("data/square.msh")

#..3/5: Retrieve elemement information 
element_types, element_ids, element_connectivity = gmsh.model.mesh.getElements(2)

#..4/5: Perform loop over the elemements
nelements = length(element_ids[1])
for element_id in 1:nelements

    #....retrieve global numbering of the local nodes of the current element
    node1_id = element_connectivity[1][3*(element_id-1)+1]
    node2_id = element_connectivity[1][3*(element_id-1)+2]
    node3_id = element_connectivity[1][3*(element_id-1)+3]

    if (false)
      println("on element ", element_id, " node-1 has global number ", node1_id)
      println("on element ", element_id, " node-2 has global number ", node2_id)
      println("on element ", element_id, " node-3 has global number ", node3_id)
      println(" ")
    end 

end 

#..5/5: Finalize gmsh
should_finalize && Gmsh.finalize()
# Out:
# Info    : Reading 'data/square.msh'...
# Info    : 9 entities
# Info    : 142 nodes
# Info    : 282 elements
# Info    : Done reading 'data/square.msh'

# %% [markdown]
# ### Section 2.2: Retrieve Node Information using the Function getNodes()
#
# We wish to retrieve the x and y coordinate of a node with a given tag (in the mesh) in the mesh.  We do so by looping over the points obtained after calling the function <i>getNodes</i>.
#
# Note that
# 1. given a 2D mesh, getNodes(0,1), getNodes(1,1) and getNodes(2,1) retrieves all the nodes that lies on point 0 (one point only), lie on line 1 and that lie on surface 1, respectively;
# 2. given a 2D mesh, getNodes() retrieves all the nodes on the mesh (including those on the boundary);

# %%
#?gmsh.model.mesh.getNodes

# %%
#..Retrieve single node 

#..1/6: Finalize gmsh
should_finalize = Gmsh.initialize()

#..2/6: Read mesh from file
gmsh.open("data/square.msh")

#..3/6: retrieve nodes from surface 
dim  = 2; 
nodeTags, node_coord, _ = gmsh.model.mesh.getNodes(dim,1)
xnode_coord = node_coord[1:3:end]; ynode_coord = node_coord[2:3:end]; znode_coord = node_coord[3:3:end];

#..4/6: test whether z-coordinates are all equal to one  
#@test znode_coord[1] ≈ 0.0

#..5/6: retrieve points from single node  
node_id = 5; 
xnode = xnode_coord[node_id]; 
ynode = ynode_coord[node_id];
znode = znode_coord[node_id];
display(xnode)
display(ynode)
display(znode)

#..6/6: Finalize gmsh
should_finalize && Gmsh.finalize();
# Out:
# Info    : Reading 'data/square.msh'...
# Info    : 9 entities
# Info    : 142 nodes
# Info    : 282 elements
# Info    : Done reading 'data/square.msh'
# 0.6500000000008002
# 0.9133974596219514
# 0.0

# %%
#..Retrieve all nodes 

#..1/6: Finalize gmsh
should_finalize = Gmsh.initialize()

#..2/6: Read mesh from file
gmsh.open("data/square.msh")

#..3/6: Retrieve elemement information 
element_types, element_ids, element_connectivity = gmsh.model.mesh.getElements(2)

#..4/6: retrieve nodes from surface 
dim  = 2; 
nodeTags, node_coord, _ = gmsh.model.mesh.getNodes()
xnode_coord = node_coord[1:3:end]; ynode_coord = node_coord[2:3:end]; 

#..5/6: Perform loop over the elemements
nelements = length(element_ids[1])
for element_id in 1:nelements

    #....retrieve global numbering of the local nodes of the current element
    node1_id = element_connectivity[1][3*(element_id-1)+1]
    node2_id = element_connectivity[1][3*(element_id-1)+2]
    node3_id = element_connectivity[1][3*(element_id-1)+3]

    xnode1 = xnode_coord[node1_id]; ynode1 = ynode_coord[node1_id]
    xnode2 = xnode_coord[node2_id]; ynode2 = ynode_coord[node2_id]
    xnode3 = xnode_coord[node3_id]; ynode3 = ynode_coord[node3_id]
    
    if (true)
      println("on element ", element_id, " node-1 has global number ", node1_id)
      println("node-1 has x-coord ",xnode1, " and y-coord ", ynode1)
      println(" ")
      println("on element ", element_id, " node-2 has global number ", node2_id)
      println("node-2 has x-coord ",xnode2, " and y-coord ", ynode2)
      println(" ")
      println("on element ", element_id, " node-3 has global number ", node3_id)
      println("node-3 has x-coord ",xnode3, " and y-coord ", ynode3)
      println(" ")
    end 

end 

#..6/6: Finalize gmsh
should_finalize && Gmsh.finalize()
# Out:
# Info    : Reading 'data/square.msh'...
# Info    : 9 entities
# Info    : 142 nodes
# Info    : 282 elements
# Info    : Done reading 'data/square.msh'
# on element 1 node-1 has global number 72
# node-1 has x-coord 0.7044542185661746 and y-coord 0.4836609274158978
#
# on element 1 node-2 has global number 81
# node-2 has x-coord 0.7535358109397505 and y-coord 0.398725467089393
#
# on element 1 node-3 has global number 102
# node-3 has x-coord 0.8167956118738324 and y-coord 0.4899817334731326
#
# on element 2 node-1 has global number 122
# node-1 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 2 node-2 has global number 76
# node-2 has x-coord 0.3000000000029347 and y-coord 0.3071796769753509
#
# on element 2 node-3 has global number 124
# node-3 has x-coord 0.2503952377171331 and y-coord 0.3884573638917699
#
# on element 3 node-1 has global number 115
# node-1 has x-coord 0.8150407418201521 and y-coord 0.8183024367054095
#
# on element 3 node-2 has global number 49
# node-2 has x-coord 0.9103703875043379 and y-coord 0.758672565470732
#
# on element 3 node-3 has global number 120
# node-3 has x-coord 0.9167537064254057 and y-coord 0.8508718537559957
#
# on element 4 node-1 has global number 106
# node-1 has x-coord 0.1856343100128922 and y-coord 0.1794039491425674
#
# on element 4 node-2 has global number 52
# node-2 has x-coord 0.0866025403788042 and y-coord 0.2500000000010402
#
# on element 4 node-3 has global number 121
# node-3 has x-coord 0.08296629115975593 and y-coord 0.1498875452108657
#
# on element 5 node-1 has global number 52
# node-1 has x-coord 0.0866025403788042 and y-coord 0.2500000000010402
#
# on element 5 node-2 has global number 106
# node-2 has x-coord 0.1856343100128922 and y-coord 0.1794039491425674
#
# on element 5 node-3 has global number 122
# node-3 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 6 node-1 has global number 49
# node-1 has x-coord 0.9103703875043379 and y-coord 0.758672565470732
#
# on element 6 node-2 has global number 115
# node-2 has x-coord 0.8150407418201521 and y-coord 0.8183024367054095
#
# on element 6 node-3 has global number 134
# node-3 has x-coord 0.8325961894321569 and y-coord 0.7301442841501415
#
# on element 7 node-1 has global number 96
# node-1 has x-coord 0.1629581819743501 and y-coord 0.3803886475363468
#
# on element 7 node-2 has global number 122
# node-2 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 7 node-3 has global number 124
# node-3 has x-coord 0.2503952377171331 and y-coord 0.3884573638917699
#
# on element 8 node-1 has global number 47
# node-1 has x-coord 0.9133974596218086 and y-coord 0.3499999999991206
#
# on element 8 node-2 has global number 86
# node-2 has x-coord 0.8109810542586341 and y-coord 0.3047536098154713
#
# on element 8 node-3 has global number 107
# node-3 has x-coord 0.9132469817449557 and y-coord 0.250891140252
#
# on element 9 node-1 has global number 52
# node-1 has x-coord 0.0866025403788042 and y-coord 0.2500000000010402
#
# on element 9 node-2 has global number 122
# node-2 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 9 node-3 has global number 125
# node-3 has x-coord 0.07972803913531296 and y-coord 0.3493512757062616
#
# on element 10 node-1 has global number 93
# node-1 has x-coord 0.1475064708395239 and y-coord 0.5596891567283323
#
# on element 10 node-2 has global number 42
# node-2 has x-coord 0.09236792741065154 and y-coord 0.4605742807381244
#
# on element 10 node-3 has global number 95
# node-3 has x-coord 0.200612550455257 and y-coord 0.4738835212418004
#
# on element 11 node-1 has global number 89
# node-1 has x-coord 0.1994089234458853 and y-coord 0.8296981761685945
#
# on element 11 node-2 has global number 53
# node-2 has x-coord 0.09056972474474832 and y-coord 0.8408174380938657
#
# on element 11 node-3 has global number 91
# node-3 has x-coord 0.1494939110587458 and y-coord 0.7431601482469268
#
# on element 12 node-1 has global number 122
# node-1 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 12 node-2 has global number 96
# node-2 has x-coord 0.1629581819743501 and y-coord 0.3803886475363468
#
# on element 12 node-3 has global number 125
# node-3 has x-coord 0.07972803913531296 and y-coord 0.3493512757062616
#
# on element 13 node-1 has global number 102
# node-1 has x-coord 0.8167956118738324 and y-coord 0.4899817334731326
#
# on element 13 node-2 has global number 81
# node-2 has x-coord 0.7535358109397505 and y-coord 0.398725467089393
#
# on element 13 node-3 has global number 127
# node-3 has x-coord 0.8406928938275637 and y-coord 0.3992789991981978
#
# on element 14 node-1 has global number 107
# node-1 has x-coord 0.9132469817449557 and y-coord 0.250891140252
#
# on element 14 node-2 has global number 86
# node-2 has x-coord 0.8109810542586341 and y-coord 0.3047536098154713
#
# on element 14 node-3 has global number 126
# node-3 has x-coord 0.8380531170040474 and y-coord 0.1999999999995608
#
# on element 15 node-1 has global number 79
# node-1 has x-coord 0.7516124797967334 and y-coord 0.5701303236396061
#
# on element 15 node-2 has global number 72
# node-2 has x-coord 0.7044542185661746 and y-coord 0.4836609274158978
#
# on element 15 node-3 has global number 102
# node-3 has x-coord 0.8167956118738324 and y-coord 0.4899817334731326
#
# on element 16 node-1 has global number 42
# node-1 has x-coord 0.09236792741065154 and y-coord 0.4605742807381244
#
# on element 16 node-2 has global number 93
# node-2 has x-coord 0.1475064708395239 and y-coord 0.5596891567283323
#
# on element 16 node-3 has global number 135
# node-3 has x-coord 0.0652562635316714 and y-coord 0.5500000000017228
#
# on element 17 node-1 has global number 91
# node-1 has x-coord 0.1494939110587458 and y-coord 0.7431601482469268
#
# on element 17 node-2 has global number 53
# node-2 has x-coord 0.09056972474474832 and y-coord 0.8408174380938657
#
# on element 17 node-3 has global number 129
# node-3 has x-coord 0.06578358757521621 and y-coord 0.7469795572487384
#
# on element 18 node-1 has global number 91
# node-1 has x-coord 0.1494939110587458 and y-coord 0.7431601482469268
#
# on element 18 node-2 has global number 46
# node-2 has x-coord 0.08885430207258693 and y-coord 0.6509201999022066
#
# on element 18 node-3 has global number 92
# node-3 has x-coord 0.1967429917984385 and y-coord 0.6534863612147314
#
# on element 19 node-1 has global number 92
# node-1 has x-coord 0.1967429917984385 and y-coord 0.6534863612147314
#
# on element 19 node-2 has global number 46
# node-2 has x-coord 0.08885430207258693 and y-coord 0.6509201999022066
#
# on element 19 node-3 has global number 93
# node-3 has x-coord 0.1475064708395239 and y-coord 0.5596891567283323
#
# on element 20 node-1 has global number 86
# node-1 has x-coord 0.8109810542586341 and y-coord 0.3047536098154713
#
# on element 20 node-2 has global number 47
# node-2 has x-coord 0.9133974596218086 and y-coord 0.3499999999991206
#
# on element 20 node-3 has global number 127
# node-3 has x-coord 0.8406928938275637 and y-coord 0.3992789991981978
#
# on element 21 node-1 has global number 95
# node-1 has x-coord 0.200612550455257 and y-coord 0.4738835212418004
#
# on element 21 node-2 has global number 42
# node-2 has x-coord 0.09236792741065154 and y-coord 0.4605742807381244
#
# on element 21 node-3 has global number 96
# node-3 has x-coord 0.1629581819743501 and y-coord 0.3803886475363468
#
# on element 22 node-1 has global number 54
# node-1 has x-coord 0.8495762630717529 and y-coord 0.9153227954948184
#
# on element 22 node-2 has global number 115
# node-2 has x-coord 0.8150407418201521 and y-coord 0.8183024367054095
#
# on element 22 node-3 has global number 120
# node-3 has x-coord 0.9167537064254057 and y-coord 0.8508718537559957
#
# on element 23 node-1 has global number 55
# node-1 has x-coord 0.1504237369277891 and y-coord 0.08467720450543256
#
# on element 23 node-2 has global number 106
# node-2 has x-coord 0.1856343100128922 and y-coord 0.1794039491425674
#
# on element 23 node-3 has global number 121
# node-3 has x-coord 0.08296629115975593 and y-coord 0.1498875452108657
#
# on element 24 node-1 has global number 83
# node-1 has x-coord 0.8000000000003898 and y-coord 0.6535898384882728
#
# on element 24 node-2 has global number 99
# node-2 has x-coord 0.8994183955992584 and y-coord 0.6528983889292931
#
# on element 24 node-3 has global number 134
# node-3 has x-coord 0.8325961894321569 and y-coord 0.7301442841501415
#
# on element 25 node-1 has global number 53
# node-1 has x-coord 0.09056972474474832 and y-coord 0.8408174380938657
#
# on element 25 node-2 has global number 89
# node-2 has x-coord 0.1994089234458853 and y-coord 0.8296981761685945
#
# on element 25 node-3 has global number 119
# node-3 has x-coord 0.1530678781041703 and y-coord 0.9178724624824317
#
# on element 26 node-1 has global number 123
# node-1 has x-coord 0.8440933898604552 and y-coord 0.09385434397709341
#
# on element 26 node-2 has global number 56
# node-2 has x-coord 0.9170502595852441 and y-coord 0.150593231699023
#
# on element 26 node-3 has global number 126
# node-3 has x-coord 0.8380531170040474 and y-coord 0.1999999999995608
#
# on element 27 node-1 has global number 86
# node-1 has x-coord 0.8109810542586341 and y-coord 0.3047536098154713
#
# on element 27 node-2 has global number 87
# node-2 has x-coord 0.7487737367126555 and y-coord 0.2215627586077865
#
# on element 27 node-3 has global number 126
# node-3 has x-coord 0.8380531170040474 and y-coord 0.1999999999995608
#
# on element 28 node-1 has global number 128
# node-1 has x-coord 0.2898261153518074 and y-coord 0.1633999302292045
#
# on element 28 node-2 has global number 48
# node-2 has x-coord 0.3475303635242556 and y-coord 0.08190748804974737
#
# on element 28 node-3 has global number 133
# node-3 has x-coord 0.3977345286928267 and y-coord 0.1553736159967032
#
# on element 29 node-1 has global number 68
# node-1 has x-coord 0.3992029949383352 and y-coord 0.4808333042715237
#
# on element 29 node-2 has global number 64
# node-2 has x-coord 0.4492890262150226 and y-coord 0.5674132367139484
#
# on element 29 node-3 has global number 97
# node-3 has x-coord 0.3488732355465848 and y-coord 0.5672558538991079
#
# on element 30 node-1 has global number 92
# node-1 has x-coord 0.1967429917984385 and y-coord 0.6534863612147314
#
# on element 30 node-2 has global number 94
# node-2 has x-coord 0.2461396475416217 and y-coord 0.5647585225755514
#
# on element 30 node-3 has global number 118
# node-3 has x-coord 0.2985524313230031 and y-coord 0.6535506656128898
#
# on element 31 node-1 has global number 99
# node-1 has x-coord 0.8994183955992584 and y-coord 0.6528983889292931
#
# on element 31 node-2 has global number 83
# node-2 has x-coord 0.8000000000003898 and y-coord 0.6535898384882728
#
# on element 31 node-3 has global number 136
# node-3 has x-coord 0.8366096411895954 and y-coord 0.5826881150315605
#
# on element 32 node-1 has global number 74
# node-1 has x-coord 0.2989417123120317 and y-coord 0.4807819782420577
#
# on element 32 node-2 has global number 94
# node-2 has x-coord 0.2461396475416217 and y-coord 0.5647585225755514
#
# on element 32 node-3 has global number 95
# node-3 has x-coord 0.200612550455257 and y-coord 0.4738835212418004
#
# on element 33 node-1 has global number 99
# node-1 has x-coord 0.8994183955992584 and y-coord 0.6528983889292931
#
# on element 33 node-2 has global number 49
# node-2 has x-coord 0.9103703875043379 and y-coord 0.758672565470732
#
# on element 33 node-3 has global number 134
# node-3 has x-coord 0.8325961894321569 and y-coord 0.7301442841501415
#
# on element 34 node-1 has global number 94
# node-1 has x-coord 0.2461396475416217 and y-coord 0.5647585225755514
#
# on element 34 node-2 has global number 97
# node-2 has x-coord 0.3488732355465848 and y-coord 0.5672558538991079
#
# on element 34 node-3 has global number 118
# node-3 has x-coord 0.2985524313230031 and y-coord 0.6535506656128898
#
# on element 35 node-1 has global number 64
# node-1 has x-coord 0.4492890262150226 and y-coord 0.5674132367139484
#
# on element 35 node-2 has global number 63
# node-2 has x-coord 0.399666032268522 and y-coord 0.6539624100660313
#
# on element 35 node-3 has global number 97
# node-3 has x-coord 0.3488732355465848 and y-coord 0.5672558538991079
#
# on element 36 node-1 has global number 74
# node-1 has x-coord 0.2989417123120317 and y-coord 0.4807819782420577
#
# on element 36 node-2 has global number 68
# node-2 has x-coord 0.3992029949383352 and y-coord 0.4808333042715237
#
# on element 36 node-3 has global number 97
# node-3 has x-coord 0.3488732355465848 and y-coord 0.5672558538991079
#
# on element 37 node-1 has global number 92
# node-1 has x-coord 0.1967429917984385 and y-coord 0.6534863612147314
#
# on element 37 node-2 has global number 93
# node-2 has x-coord 0.1475064708395239 and y-coord 0.5596891567283323
#
# on element 37 node-3 has global number 94
# node-3 has x-coord 0.2461396475416217 and y-coord 0.5647585225755514
#
# on element 38 node-1 has global number 123
# node-1 has x-coord 0.8440933898604552 and y-coord 0.09385434397709341
#
# on element 38 node-2 has global number 126
# node-2 has x-coord 0.8380531170040474 and y-coord 0.1999999999995608
#
# on element 38 node-3 has global number 142
# node-3 has x-coord 0.7753798093615702 and y-coord 0.1497198395936735
#
# on element 39 node-1 has global number 46
# node-1 has x-coord 0.08885430207258693 and y-coord 0.6509201999022066
#
# on element 39 node-2 has global number 91
# node-2 has x-coord 0.1494939110587458 and y-coord 0.7431601482469268
#
# on element 39 node-3 has global number 129
# node-3 has x-coord 0.06578358757521621 and y-coord 0.7469795572487384
#
# on element 40 node-1 has global number 74
# node-1 has x-coord 0.2989417123120317 and y-coord 0.4807819782420577
#
# on element 40 node-2 has global number 95
# node-2 has x-coord 0.200612550455257 and y-coord 0.4738835212418004
#
# on element 40 node-3 has global number 124
# node-3 has x-coord 0.2503952377171331 and y-coord 0.3884573638917699
#
# on element 41 node-1 has global number 110
# node-1 has x-coord 0.3492006954957157 and y-coord 0.2288327370242559
#
# on element 41 node-2 has global number 128
# node-2 has x-coord 0.2898261153518074 and y-coord 0.1633999302292045
#
# on element 41 node-3 has global number 133
# node-3 has x-coord 0.3977345286928267 and y-coord 0.1553736159967032
#
# on element 42 node-1 has global number 76
# node-1 has x-coord 0.3000000000029347 and y-coord 0.3071796769753509
#
# on element 42 node-2 has global number 122
# node-2 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 42 node-3 has global number 137
# node-3 has x-coord 0.2613872612265493 and y-coord 0.2359890604552144
#
# on element 43 node-1 has global number 94
# node-1 has x-coord 0.2461396475416217 and y-coord 0.5647585225755514
#
# on element 43 node-2 has global number 93
# node-2 has x-coord 0.1475064708395239 and y-coord 0.5596891567283323
#
# on element 43 node-3 has global number 95
# node-3 has x-coord 0.200612550455257 and y-coord 0.4738835212418004
#
# on element 44 node-1 has global number 94
# node-1 has x-coord 0.2461396475416217 and y-coord 0.5647585225755514
#
# on element 44 node-2 has global number 74
# node-2 has x-coord 0.2989417123120317 and y-coord 0.4807819782420577
#
# on element 44 node-3 has global number 97
# node-3 has x-coord 0.3488732355465848 and y-coord 0.5672558538991079
#
# on element 45 node-1 has global number 41
# node-1 has x-coord 0.4500000000018615 and y-coord 0.9133974596216763
#
# on element 45 node-2 has global number 57
# node-2 has x-coord 0.3501362169619658 and y-coord 0.913476104520136
#
# on element 45 node-3 has global number 58
# node-3 has x-coord 0.4000227028286923 and y-coord 0.8268080267265111
#
# on element 46 node-1 has global number 41
# node-1 has x-coord 0.4500000000018615 and y-coord 0.9133974596216763
#
# on element 46 node-2 has global number 28
# node-2 has x-coord 0.4000000000016644 and y-coord 1.0
#
# on element 46 node-3 has global number 57
# node-3 has x-coord 0.3501362169619658 and y-coord 0.913476104520136
#
# on element 47 node-1 has global number 27
# node-1 has x-coord 0.5000000000020587 and y-coord 1.0
#
# on element 47 node-2 has global number 28
# node-2 has x-coord 0.4000000000016644 and y-coord 1.0
#
# on element 47 node-3 has global number 41
# node-3 has x-coord 0.4500000000018615 and y-coord 0.9133974596216763
#
# on element 48 node-1 has global number 88
# node-1 has x-coord 0.3001627035935244 and y-coord 0.8268888562051476
#
# on element 48 node-2 has global number 50
# node-2 has x-coord 0.250817301762687 and y-coord 0.9138693290130382
#
# on element 48 node-3 has global number 89
# node-3 has x-coord 0.1994089234458853 and y-coord 0.8296981761685945
#
# on element 49 node-1 has global number 36
# node-1 has x-coord 0.0 and y-coord 0.5000000000020587
#
# on element 49 node-2 has global number 37
# node-2 has x-coord 0.0 and y-coord 0.4000000000016644
#
# on element 49 node-3 has global number 42
# node-3 has x-coord 0.09236792741065154 and y-coord 0.4605742807381244
#
# on element 50 node-1 has global number 98
# node-1 has x-coord 0.600000858364031 and y-coord 0.8267954148199794
#
# on element 50 node-2 has global number 45
# node-2 has x-coord 0.6500000000008002 and y-coord 0.9133974596219514
#
# on element 50 node-3 has global number 104
# node-3 has x-coord 0.5500007736960177 and y-coord 0.9133979063146329
#
# on element 51 node-1 has global number 44
# node-1 has x-coord 0.9152217186777627 and y-coord 0.5468402906274978
#
# on element 51 node-2 has global number 19
# node-2 has x-coord 1.0 and y-coord 0.5999999999989468
#
# on element 51 node-3 has global number 99
# node-3 has x-coord 0.8994183955992584 and y-coord 0.6528983889292931
#
# on element 52 node-1 has global number 45
# node-1 has x-coord 0.6500000000008002 and y-coord 0.9133974596219514
#
# on element 52 node-2 has global number 26
# node-2 has x-coord 0.6000000000013869 and y-coord 1.0
#
# on element 52 node-3 has global number 104
# node-3 has x-coord 0.5500007736960177 and y-coord 0.9133979063146329
#
# on element 53 node-1 has global number 57
# node-1 has x-coord 0.3501362169619658 and y-coord 0.913476104520136
#
# on element 53 node-2 has global number 50
# node-2 has x-coord 0.250817301762687 and y-coord 0.9138693290130382
#
# on element 53 node-3 has global number 88
# node-3 has x-coord 0.3001627035935244 and y-coord 0.8268888562051476
#
# on element 54 node-1 has global number 88
# node-1 has x-coord 0.3001627035935244 and y-coord 0.8268888562051476
#
# on element 54 node-2 has global number 89
# node-2 has x-coord 0.1994089234458853 and y-coord 0.8296981761685945
#
# on element 54 node-3 has global number 90
# node-3 has x-coord 0.2499286045088537 and y-coord 0.7410578833522041
#
# on element 55 node-1 has global number 43
# node-1 has x-coord 0.5499999999988205 and y-coord 0.08660254037843171
#
# on element 55 node-2 has global number 10
# node-2 has x-coord 0.5999999999989468 and y-coord 0.0
#
# on element 55 node-3 has global number 100
# node-3 has x-coord 0.6499999999991333 and y-coord 0.08660254037864011
#
# on element 56 node-1 has global number 27
# node-1 has x-coord 0.5000000000020587 and y-coord 1.0
#
# on element 56 node-2 has global number 41
# node-2 has x-coord 0.4500000000018615 and y-coord 0.9133974596216763
#
# on element 56 node-3 has global number 104
# node-3 has x-coord 0.5500007736960177 and y-coord 0.9133979063146329
#
# on element 57 node-1 has global number 29
# node-1 has x-coord 0.3000000000012483 and y-coord 1.0
#
# on element 57 node-2 has global number 50
# node-2 has x-coord 0.250817301762687 and y-coord 0.9138693290130382
#
# on element 57 node-3 has global number 57
# node-3 has x-coord 0.3501362169619658 and y-coord 0.913476104520136
#
# on element 58 node-1 has global number 18
# node-1 has x-coord 1.0 and y-coord 0.4999999999986943
#
# on element 58 node-2 has global number 19
# node-2 has x-coord 1.0 and y-coord 0.5999999999989468
#
# on element 58 node-3 has global number 44
# node-3 has x-coord 0.9152217186777627 and y-coord 0.5468402906274978
#
# on element 59 node-1 has global number 9
# node-1 has x-coord 0.4999999999986943 and y-coord 0.0
#
# on element 59 node-2 has global number 10
# node-2 has x-coord 0.5999999999989468 and y-coord 0.0
#
# on element 59 node-3 has global number 43
# node-3 has x-coord 0.5499999999988205 and y-coord 0.08660254037843171
#
# on element 60 node-1 has global number 41
# node-1 has x-coord 0.4500000000018615 and y-coord 0.9133974596216763
#
# on element 60 node-2 has global number 58
# node-2 has x-coord 0.4000227028286923 and y-coord 0.8268080267265111
#
# on element 60 node-3 has global number 59
# node-3 has x-coord 0.5000037838059685 and y-coord 0.8267971038241899
#
# on element 61 node-1 has global number 28
# node-1 has x-coord 0.4000000000016644 and y-coord 1.0
#
# on element 61 node-2 has global number 29
# node-2 has x-coord 0.3000000000012483 and y-coord 1.0
#
# on element 61 node-3 has global number 57
# node-3 has x-coord 0.3501362169619658 and y-coord 0.913476104520136
#
# on element 62 node-1 has global number 26
# node-1 has x-coord 0.6000000000013869 and y-coord 1.0
#
# on element 62 node-2 has global number 27
# node-2 has x-coord 0.5000000000020587 and y-coord 1.0
#
# on element 62 node-3 has global number 104
# node-3 has x-coord 0.5500007736960177 and y-coord 0.9133979063146329
#
# on element 63 node-1 has global number 18
# node-1 has x-coord 1.0 and y-coord 0.4999999999986943
#
# on element 63 node-2 has global number 44
# node-2 has x-coord 0.9152217186777627 and y-coord 0.5468402906274978
#
# on element 63 node-3 has global number 101
# node-3 has x-coord 0.9157740970141776 and y-coord 0.4494733817703521
#
# on element 64 node-1 has global number 48
# node-1 has x-coord 0.3475303635242556 and y-coord 0.08190748804974737
#
# on element 64 node-2 has global number 8
# node-2 has x-coord 0.3999999999989749 and y-coord 0.0
#
# on element 64 node-3 has global number 103
# node-3 has x-coord 0.4498499977837827 and y-coord 0.08393456559302379
#
# on element 65 node-1 has global number 9
# node-1 has x-coord 0.4999999999986943 and y-coord 0.0
#
# on element 65 node-2 has global number 43
# node-2 has x-coord 0.5499999999988205 and y-coord 0.08660254037843171
#
# on element 65 node-3 has global number 103
# node-3 has x-coord 0.4498499977837827 and y-coord 0.08393456559302379
#
# on element 66 node-1 has global number 47
# node-1 has x-coord 0.9133974596218086 and y-coord 0.3499999999991206
#
# on element 66 node-2 has global number 17
# node-2 has x-coord 1.0 and y-coord 0.3999999999989749
#
# on element 66 node-3 has global number 101
# node-3 has x-coord 0.9157740970141776 and y-coord 0.4494733817703521
#
# on element 67 node-1 has global number 90
# node-1 has x-coord 0.2499286045088537 and y-coord 0.7410578833522041
#
# on element 67 node-2 has global number 89
# node-2 has x-coord 0.1994089234458853 and y-coord 0.8296981761685945
#
# on element 67 node-3 has global number 91
# node-3 has x-coord 0.1494939110587458 and y-coord 0.7431601482469268
#
# on element 68 node-1 has global number 20
# node-1 has x-coord 1.0 and y-coord 0.69999999999921
#
# on element 68 node-2 has global number 49
# node-2 has x-coord 0.9103703875043379 and y-coord 0.758672565470732
#
# on element 68 node-3 has global number 99
# node-3 has x-coord 0.8994183955992584 and y-coord 0.6528983889292931
#
# on element 69 node-1 has global number 41
# node-1 has x-coord 0.4500000000018615 and y-coord 0.9133974596216763
#
# on element 69 node-2 has global number 59
# node-2 has x-coord 0.5000037838059685 and y-coord 0.8267971038241899
#
# on element 69 node-3 has global number 104
# node-3 has x-coord 0.5500007736960177 and y-coord 0.9133979063146329
#
# on element 70 node-1 has global number 45
# node-1 has x-coord 0.6500000000008002 and y-coord 0.9133974596219514
#
# on element 70 node-2 has global number 98
# node-2 has x-coord 0.600000858364031 and y-coord 0.8267954148199794
#
# on element 70 node-3 has global number 113
# node-3 has x-coord 0.6994408893754028 and y-coord 0.8265574229272842
#
# on element 71 node-1 has global number 8
# node-1 has x-coord 0.3999999999989749 and y-coord 0.0
#
# on element 71 node-2 has global number 9
# node-2 has x-coord 0.4999999999986943 and y-coord 0.0
#
# on element 71 node-3 has global number 103
# node-3 has x-coord 0.4498499977837827 and y-coord 0.08393456559302379
#
# on element 72 node-1 has global number 11
# node-1 has x-coord 0.69999999999921 and y-coord 0.0
#
# on element 72 node-2 has global number 51
# node-2 has x-coord 0.7459788032314767 and y-coord 0.07959225689678907
#
# on element 72 node-3 has global number 100
# node-3 has x-coord 0.6499999999991333 and y-coord 0.08660254037864011
#
# on element 73 node-1 has global number 17
# node-1 has x-coord 1.0 and y-coord 0.3999999999989749
#
# on element 73 node-2 has global number 18
# node-2 has x-coord 1.0 and y-coord 0.4999999999986943
#
# on element 73 node-3 has global number 101
# node-3 has x-coord 0.9157740970141776 and y-coord 0.4494733817703521
#
# on element 74 node-1 has global number 90
# node-1 has x-coord 0.2499286045088537 and y-coord 0.7410578833522041
#
# on element 74 node-2 has global number 91
# node-2 has x-coord 0.1494939110587458 and y-coord 0.7431601482469268
#
# on element 74 node-3 has global number 92
# node-3 has x-coord 0.1967429917984385 and y-coord 0.6534863612147314
#
# on element 75 node-1 has global number 19
# node-1 has x-coord 1.0 and y-coord 0.5999999999989468
#
# on element 75 node-2 has global number 20
# node-2 has x-coord 1.0 and y-coord 0.69999999999921
#
# on element 75 node-3 has global number 99
# node-3 has x-coord 0.8994183955992584 and y-coord 0.6528983889292931
#
# on element 76 node-1 has global number 59
# node-1 has x-coord 0.5000037838059685 and y-coord 0.8267971038241899
#
# on element 76 node-2 has global number 98
# node-2 has x-coord 0.600000858364031 and y-coord 0.8267954148199794
#
# on element 76 node-3 has global number 104
# node-3 has x-coord 0.5500007736960177 and y-coord 0.9133979063146329
#
# on element 77 node-1 has global number 10
# node-1 has x-coord 0.5999999999989468 and y-coord 0.0
#
# on element 77 node-2 has global number 11
# node-2 has x-coord 0.69999999999921 and y-coord 0.0
#
# on element 77 node-3 has global number 100
# node-3 has x-coord 0.6499999999991333 and y-coord 0.08660254037864011
#
# on element 78 node-1 has global number 29
# node-1 has x-coord 0.3000000000012483 and y-coord 1.0
#
# on element 78 node-2 has global number 30
# node-2 has x-coord 0.2000000000008322 and y-coord 1.0
#
# on element 78 node-3 has global number 50
# node-3 has x-coord 0.250817301762687 and y-coord 0.9138693290130382
#
# on element 79 node-1 has global number 109
# node-1 has x-coord 0.7499293771789075 and y-coord 0.9137183489341748
#
# on element 79 node-2 has global number 113
# node-2 has x-coord 0.6994408893754028 and y-coord 0.8265574229272842
#
# on element 79 node-3 has global number 115
# node-3 has x-coord 0.8150407418201521 and y-coord 0.8183024367054095
#
# on element 80 node-1 has global number 20
# node-1 has x-coord 1.0 and y-coord 0.69999999999921
#
# on element 80 node-2 has global number 21
# node-2 has x-coord 1.0 and y-coord 0.7999999999994734
#
# on element 80 node-3 has global number 49
# node-3 has x-coord 0.9103703875043379 and y-coord 0.758672565470732
#
# on element 81 node-1 has global number 38
# node-1 has x-coord 0.0 and y-coord 0.3000000000012483
#
# on element 81 node-2 has global number 39
# node-2 has x-coord 0.0 and y-coord 0.2000000000008322
#
# on element 81 node-3 has global number 52
# node-3 has x-coord 0.0866025403788042 and y-coord 0.2500000000010402
#
# on element 82 node-1 has global number 101
# node-1 has x-coord 0.9157740970141776 and y-coord 0.4494733817703521
#
# on element 82 node-2 has global number 44
# node-2 has x-coord 0.9152217186777627 and y-coord 0.5468402906274978
#
# on element 82 node-3 has global number 102
# node-3 has x-coord 0.8167956118738324 and y-coord 0.4899817334731326
#
# on element 83 node-1 has global number 109
# node-1 has x-coord 0.7499293771789075 and y-coord 0.9137183489341748
#
# on element 83 node-2 has global number 45
# node-2 has x-coord 0.6500000000008002 and y-coord 0.9133974596219514
#
# on element 83 node-3 has global number 113
# node-3 has x-coord 0.6994408893754028 and y-coord 0.8265574229272842
#
# on element 84 node-1 has global number 11
# node-1 has x-coord 0.69999999999921 and y-coord 0.0
#
# on element 84 node-2 has global number 12
# node-2 has x-coord 0.7999999999994734 and y-coord 0.0
#
# on element 84 node-3 has global number 51
# node-3 has x-coord 0.7459788032314767 and y-coord 0.07959225689678907
#
# on element 85 node-1 has global number 59
# node-1 has x-coord 0.5000037838059685 and y-coord 0.8267971038241899
#
# on element 85 node-2 has global number 58
# node-2 has x-coord 0.4000227028286923 and y-coord 0.8268080267265111
#
# on element 85 node-3 has global number 60
# node-3 has x-coord 0.4500044144404199 and y-coord 0.7401949275428532
#
# on element 86 node-1 has global number 23
# node-1 has x-coord 0.8999999999995836 and y-coord 1.0
#
# on element 86 node-2 has global number 24
# node-2 has x-coord 0.7999999999999998 and y-coord 1.0
#
# on element 86 node-3 has global number 54
# node-3 has x-coord 0.8495762630717529 and y-coord 0.9153227954948184
#
# on element 87 node-1 has global number 7
# node-1 has x-coord 0.2999999999992664 and y-coord 0.0
#
# on element 87 node-2 has global number 8
# node-2 has x-coord 0.3999999999989749 and y-coord 0.0
#
# on element 87 node-3 has global number 48
# node-3 has x-coord 0.3475303635242556 and y-coord 0.08190748804974737
#
# on element 88 node-1 has global number 70
# node-1 has x-coord 0.3508014145113765 and y-coord 0.3944261231392702
#
# on element 88 node-2 has global number 68
# node-2 has x-coord 0.3992029949383352 and y-coord 0.4808333042715237
#
# on element 88 node-3 has global number 74
# node-3 has x-coord 0.2989417123120317 and y-coord 0.4807819782420577
#
# on element 89 node-1 has global number 32
# node-1 has x-coord 0.0 and y-coord 0.8999999999995836
#
# on element 89 node-2 has global number 33
# node-2 has x-coord 0.0 and y-coord 0.7999999999999998
#
# on element 89 node-3 has global number 53
# node-3 has x-coord 0.09056972474474832 and y-coord 0.8408174380938657
#
# on element 90 node-1 has global number 16
# node-1 has x-coord 1.0 and y-coord 0.2999999999992664
#
# on element 90 node-2 has global number 17
# node-2 has x-coord 1.0 and y-coord 0.3999999999989749
#
# on element 90 node-3 has global number 47
# node-3 has x-coord 0.9133974596218086 and y-coord 0.3499999999991206
#
# on element 91 node-1 has global number 62
# node-1 has x-coord 0.5000009634704368 and y-coord 0.6535903947466356
#
# on element 91 node-2 has global number 60
# node-2 has x-coord 0.4500044144404199 and y-coord 0.7401949275428532
#
# on element 91 node-3 has global number 63
# node-3 has x-coord 0.399666032268522 and y-coord 0.6539624100660313
#
# on element 92 node-1 has global number 66
# node-1 has x-coord 0.4998617818618989 and y-coord 0.4804675945786104
#
# on element 92 node-2 has global number 64
# node-2 has x-coord 0.4492890262150226 and y-coord 0.5674132367139484
#
# on element 92 node-3 has global number 68
# node-3 has x-coord 0.3992029949383352 and y-coord 0.4808333042715237
#
# on element 93 node-1 has global number 58
# node-1 has x-coord 0.4000227028286923 and y-coord 0.8268080267265111
#
# on element 93 node-2 has global number 57
# node-2 has x-coord 0.3501362169619658 and y-coord 0.913476104520136
#
# on element 93 node-3 has global number 88
# node-3 has x-coord 0.3001627035935244 and y-coord 0.8268888562051476
#
# on element 94 node-1 has global number 7
# node-1 has x-coord 0.2999999999992664 and y-coord 0.0
#
# on element 94 node-2 has global number 48
# node-2 has x-coord 0.3475303635242556 and y-coord 0.08190748804974737
#
# on element 94 node-3 has global number 105
# node-3 has x-coord 0.2471893802660856 and y-coord 0.08407329706072986
#
# on element 95 node-1 has global number 80
# node-1 has x-coord 0.700264271802365 and y-coord 0.654116363179049
#
# on element 95 node-2 has global number 84
# node-2 has x-coord 0.747143410205979 and y-coord 0.7386054505286098
#
# on element 95 node-3 has global number 112
# node-3 has x-coord 0.6495716905027349 and y-coord 0.7400329444146921
#
# on element 96 node-1 has global number 34
# node-1 has x-coord 0.0 and y-coord 0.7000000000006934
#
# on element 96 node-2 has global number 35
# node-2 has x-coord 0.0 and y-coord 0.6000000000013869
#
# on element 96 node-3 has global number 46
# node-3 has x-coord 0.08885430207258693 and y-coord 0.6509201999022066
#
# on element 97 node-1 has global number 66
# node-1 has x-coord 0.4998617818618989 and y-coord 0.4804675945786104
#
# on element 97 node-2 has global number 68
# node-2 has x-coord 0.3992029949383352 and y-coord 0.4808333042715237
#
# on element 97 node-3 has global number 69
# node-3 has x-coord 0.4498441294682426 and y-coord 0.3938707812513983
#
# on element 98 node-1 has global number 69
# node-1 has x-coord 0.4498441294682426 and y-coord 0.3938707812513983
#
# on element 98 node-2 has global number 75
# node-2 has x-coord 0.4001075906650136 and y-coord 0.3073017552560426
#
# on element 98 node-3 has global number 77
# node-3 has x-coord 0.4999919533568911 and y-coord 0.3072147840053002
#
# on element 99 node-1 has global number 16
# node-1 has x-coord 1.0 and y-coord 0.2999999999992664
#
# on element 99 node-2 has global number 47
# node-2 has x-coord 0.9133974596218086 and y-coord 0.3499999999991206
#
# on element 99 node-3 has global number 107
# node-3 has x-coord 0.9132469817449557 and y-coord 0.250891140252
#
# on element 100 node-1 has global number 65
# node-1 has x-coord 0.5498816649485171 and y-coord 0.5670583805869821
#
# on element 100 node-2 has global number 67
# node-2 has x-coord 0.5999572411359403 and y-coord 0.4804104109524933
#
# on element 100 node-3 has global number 71
# node-3 has x-coord 0.6499731510146851 and y-coord 0.5670034207262449
#
# on element 101 node-1 has global number 25
# node-1 has x-coord 0.7000000000006934 and y-coord 1.0
#
# on element 101 node-2 has global number 26
# node-2 has x-coord 0.6000000000013869 and y-coord 1.0
#
# on element 101 node-3 has global number 45
# node-3 has x-coord 0.6500000000008002 and y-coord 0.9133974596219514
#
# on element 102 node-1 has global number 80
# node-1 has x-coord 0.700264271802365 and y-coord 0.654116363179049
#
# on element 102 node-2 has global number 83
# node-2 has x-coord 0.8000000000003898 and y-coord 0.6535898384882728
#
# on element 102 node-3 has global number 84
# node-3 has x-coord 0.747143410205979 and y-coord 0.7386054505286098
#
# on element 103 node-1 has global number 15
# node-1 has x-coord 1.0 and y-coord 0.1999999999995579
#
# on element 103 node-2 has global number 16
# node-2 has x-coord 1.0 and y-coord 0.2999999999992664
#
# on element 103 node-3 has global number 107
# node-3 has x-coord 0.9132469817449557 and y-coord 0.250891140252
#
# on element 104 node-1 has global number 71
# node-1 has x-coord 0.6499731510146851 and y-coord 0.5670034207262449
#
# on element 104 node-2 has global number 72
# node-2 has x-coord 0.7044542185661746 and y-coord 0.4836609274158978
#
# on element 104 node-3 has global number 79
# node-3 has x-coord 0.7516124797967334 and y-coord 0.5701303236396061
#
# on element 105 node-1 has global number 71
# node-1 has x-coord 0.6499731510146851 and y-coord 0.5670034207262449
#
# on element 105 node-2 has global number 79
# node-2 has x-coord 0.7516124797967334 and y-coord 0.5701303236396061
#
# on element 105 node-3 has global number 80
# node-3 has x-coord 0.700264271802365 and y-coord 0.654116363179049
#
# on element 106 node-1 has global number 62
# node-1 has x-coord 0.5000009634704368 and y-coord 0.6535903947466356
#
# on element 106 node-2 has global number 63
# node-2 has x-coord 0.399666032268522 and y-coord 0.6539624100660313
#
# on element 106 node-3 has global number 64
# node-3 has x-coord 0.4492890262150226 and y-coord 0.5674132367139484
#
# on element 107 node-1 has global number 6
# node-1 has x-coord 0.1999999999995579 and y-coord 0.0
#
# on element 107 node-2 has global number 7
# node-2 has x-coord 0.2999999999992664 and y-coord 0.0
#
# on element 107 node-3 has global number 105
# node-3 has x-coord 0.2471893802660856 and y-coord 0.08407329706072986
#
# on element 108 node-1 has global number 71
# node-1 has x-coord 0.6499731510146851 and y-coord 0.5670034207262449
#
# on element 108 node-2 has global number 67
# node-2 has x-coord 0.5999572411359403 and y-coord 0.4804104109524933
#
# on element 108 node-3 has global number 72
# node-3 has x-coord 0.7044542185661746 and y-coord 0.4836609274158978
#
# on element 109 node-1 has global number 65
# node-1 has x-coord 0.5498816649485171 and y-coord 0.5670583805869821
#
# on element 109 node-2 has global number 64
# node-2 has x-coord 0.4492890262150226 and y-coord 0.5674132367139484
#
# on element 109 node-3 has global number 66
# node-3 has x-coord 0.4998617818618989 and y-coord 0.4804675945786104
#
# on element 110 node-1 has global number 65
# node-1 has x-coord 0.5498816649485171 and y-coord 0.5670583805869821
#
# on element 110 node-2 has global number 66
# node-2 has x-coord 0.4998617818618989 and y-coord 0.4804675945786104
#
# on element 110 node-3 has global number 67
# node-3 has x-coord 0.5999572411359403 and y-coord 0.4804104109524933
#
# on element 111 node-1 has global number 77
# node-1 has x-coord 0.4999919533568911 and y-coord 0.3072147840053002
#
# on element 111 node-2 has global number 75
# node-2 has x-coord 0.4001075906650136 and y-coord 0.3073017552560426
#
# on element 111 node-3 has global number 78
# node-3 has x-coord 0.4500000000024984 and y-coord 0.22057713659739
#
# on element 112 node-1 has global number 71
# node-1 has x-coord 0.6499731510146851 and y-coord 0.5670034207262449
#
# on element 112 node-2 has global number 80
# node-2 has x-coord 0.700264271802365 and y-coord 0.654116363179049
#
# on element 112 node-3 has global number 108
# node-3 has x-coord 0.6000202362686526 and y-coord 0.6536923509744805
#
# on element 113 node-1 has global number 62
# node-1 has x-coord 0.5000009634704368 and y-coord 0.6535903947466356
#
# on element 113 node-2 has global number 64
# node-2 has x-coord 0.4492890262150226 and y-coord 0.5674132367139484
#
# on element 113 node-3 has global number 65
# node-3 has x-coord 0.5498816649485171 and y-coord 0.5670583805869821
#
# on element 114 node-1 has global number 77
# node-1 has x-coord 0.4999919533568911 and y-coord 0.3072147840053002
#
# on element 114 node-2 has global number 78
# node-2 has x-coord 0.4500000000024984 and y-coord 0.22057713659739
#
# on element 114 node-3 has global number 85
# node-3 has x-coord 0.5500000000021426 and y-coord 0.2205771365975499
#
# on element 115 node-1 has global number 59
# node-1 has x-coord 0.5000037838059685 and y-coord 0.8267971038241899
#
# on element 115 node-2 has global number 61
# node-2 has x-coord 0.5500013663751491 and y-coord 0.7401931677420538
#
# on element 115 node-3 has global number 98
# node-3 has x-coord 0.600000858364031 and y-coord 0.8267954148199794
#
# on element 116 node-1 has global number 62
# node-1 has x-coord 0.5000009634704368 and y-coord 0.6535903947466356
#
# on element 116 node-2 has global number 65
# node-2 has x-coord 0.5498816649485171 and y-coord 0.5670583805869821
#
# on element 116 node-3 has global number 108
# node-3 has x-coord 0.6000202362686526 and y-coord 0.6536923509744805
#
# on element 117 node-1 has global number 65
# node-1 has x-coord 0.5498816649485171 and y-coord 0.5670583805869821
#
# on element 117 node-2 has global number 71
# node-2 has x-coord 0.6499731510146851 and y-coord 0.5670034207262449
#
# on element 117 node-3 has global number 108
# node-3 has x-coord 0.6000202362686526 and y-coord 0.6536923509744805
#
# on element 118 node-1 has global number 14
# node-1 has x-coord 1.0 and y-coord 0.09999999999981467
#
# on element 118 node-2 has global number 15
# node-2 has x-coord 1.0 and y-coord 0.1999999999995579
#
# on element 118 node-3 has global number 56
# node-3 has x-coord 0.9170502595852441 and y-coord 0.150593231699023
#
# on element 119 node-1 has global number 78
# node-1 has x-coord 0.4500000000024984 and y-coord 0.22057713659739
#
# on element 119 node-2 has global number 75
# node-2 has x-coord 0.4001075906650136 and y-coord 0.3073017552560426
#
# on element 119 node-3 has global number 110
# node-3 has x-coord 0.3492006954957157 and y-coord 0.2288327370242559
#
# on element 120 node-1 has global number 98
# node-1 has x-coord 0.600000858364031 and y-coord 0.8267954148199794
#
# on element 120 node-2 has global number 61
# node-2 has x-coord 0.5500013663751491 and y-coord 0.7401931677420538
#
# on element 120 node-3 has global number 112
# node-3 has x-coord 0.6495716905027349 and y-coord 0.7400329444146921
#
# on element 121 node-1 has global number 72
# node-1 has x-coord 0.7044542185661746 and y-coord 0.4836609274158978
#
# on element 121 node-2 has global number 73
# node-2 has x-coord 0.6507352432846287 and y-coord 0.3943325211712257
#
# on element 121 node-3 has global number 81
# node-3 has x-coord 0.7535358109397505 and y-coord 0.398725467089393
#
# on element 122 node-1 has global number 69
# node-1 has x-coord 0.4498441294682426 and y-coord 0.3938707812513983
#
# on element 122 node-2 has global number 70
# node-2 has x-coord 0.3508014145113765 and y-coord 0.3944261231392702
#
# on element 122 node-3 has global number 75
# node-3 has x-coord 0.4001075906650136 and y-coord 0.3073017552560426
#
# on element 123 node-1 has global number 81
# node-1 has x-coord 0.7535358109397505 and y-coord 0.398725467089393
#
# on element 123 node-2 has global number 82
# node-2 has x-coord 0.7000000000012385 and y-coord 0.3071796769756584
#
# on element 123 node-3 has global number 86
# node-3 has x-coord 0.8109810542586341 and y-coord 0.3047536098154713
#
# on element 124 node-1 has global number 66
# node-1 has x-coord 0.4998617818618989 and y-coord 0.4804675945786104
#
# on element 124 node-2 has global number 69
# node-2 has x-coord 0.4498441294682426 and y-coord 0.3938707812513983
#
# on element 124 node-3 has global number 111
# node-3 has x-coord 0.5500650581848795 and y-coord 0.3939126281557884
#
# on element 125 node-1 has global number 61
# node-1 has x-coord 0.5500013663751491 and y-coord 0.7401931677420538
#
# on element 125 node-2 has global number 60
# node-2 has x-coord 0.4500044144404199 and y-coord 0.7401949275428532
#
# on element 125 node-3 has global number 62
# node-3 has x-coord 0.5000009634704368 and y-coord 0.6535903947466356
#
# on element 126 node-1 has global number 5
# node-1 has x-coord 0.09999999999981467 and y-coord 0.0
#
# on element 126 node-2 has global number 6
# node-2 has x-coord 0.1999999999995579 and y-coord 0.0
#
# on element 126 node-3 has global number 55
# node-3 has x-coord 0.1504237369277891 and y-coord 0.08467720450543256
#
# on element 127 node-1 has global number 72
# node-1 has x-coord 0.7044542185661746 and y-coord 0.4836609274158978
#
# on element 127 node-2 has global number 67
# node-2 has x-coord 0.5999572411359403 and y-coord 0.4804104109524933
#
# on element 127 node-3 has global number 73
# node-3 has x-coord 0.6507352432846287 and y-coord 0.3943325211712257
#
# on element 128 node-1 has global number 67
# node-1 has x-coord 0.5999572411359403 and y-coord 0.4804104109524933
#
# on element 128 node-2 has global number 66
# node-2 has x-coord 0.4998617818618989 and y-coord 0.4804675945786104
#
# on element 128 node-3 has global number 111
# node-3 has x-coord 0.5500650581848795 and y-coord 0.3939126281557884
#
# on element 129 node-1 has global number 59
# node-1 has x-coord 0.5000037838059685 and y-coord 0.8267971038241899
#
# on element 129 node-2 has global number 60
# node-2 has x-coord 0.4500044144404199 and y-coord 0.7401949275428532
#
# on element 129 node-3 has global number 61
# node-3 has x-coord 0.5500013663751491 and y-coord 0.7401931677420538
#
# on element 130 node-1 has global number 61
# node-1 has x-coord 0.5500013663751491 and y-coord 0.7401931677420538
#
# on element 130 node-2 has global number 62
# node-2 has x-coord 0.5000009634704368 and y-coord 0.6535903947466356
#
# on element 130 node-3 has global number 108
# node-3 has x-coord 0.6000202362686526 and y-coord 0.6536923509744805
#
# on element 131 node-1 has global number 54
# node-1 has x-coord 0.8495762630717529 and y-coord 0.9153227954948184
#
# on element 131 node-2 has global number 24
# node-2 has x-coord 0.7999999999999998 and y-coord 1.0
#
# on element 131 node-3 has global number 109
# node-3 has x-coord 0.7499293771789075 and y-coord 0.9137183489341748
#
# on element 132 node-1 has global number 69
# node-1 has x-coord 0.4498441294682426 and y-coord 0.3938707812513983
#
# on element 132 node-2 has global number 68
# node-2 has x-coord 0.3992029949383352 and y-coord 0.4808333042715237
#
# on element 132 node-3 has global number 70
# node-3 has x-coord 0.3508014145113765 and y-coord 0.3944261231392702
#
# on element 133 node-1 has global number 24
# node-1 has x-coord 0.7999999999999998 and y-coord 1.0
#
# on element 133 node-2 has global number 25
# node-2 has x-coord 0.7000000000006934 and y-coord 1.0
#
# on element 133 node-3 has global number 109
# node-3 has x-coord 0.7499293771789075 and y-coord 0.9137183489341748
#
# on element 134 node-1 has global number 56
# node-1 has x-coord 0.9170502595852441 and y-coord 0.150593231699023
#
# on element 134 node-2 has global number 15
# node-2 has x-coord 1.0 and y-coord 0.1999999999995579
#
# on element 134 node-3 has global number 107
# node-3 has x-coord 0.9132469817449557 and y-coord 0.250891140252
#
# on element 135 node-1 has global number 69
# node-1 has x-coord 0.4498441294682426 and y-coord 0.3938707812513983
#
# on element 135 node-2 has global number 77
# node-2 has x-coord 0.4999919533568911 and y-coord 0.3072147840053002
#
# on element 135 node-3 has global number 111
# node-3 has x-coord 0.5500650581848795 and y-coord 0.3939126281557884
#
# on element 136 node-1 has global number 61
# node-1 has x-coord 0.5500013663751491 and y-coord 0.7401931677420538
#
# on element 136 node-2 has global number 108
# node-2 has x-coord 0.6000202362686526 and y-coord 0.6536923509744805
#
# on element 136 node-3 has global number 112
# node-3 has x-coord 0.6495716905027349 and y-coord 0.7400329444146921
#
# on element 137 node-1 has global number 80
# node-1 has x-coord 0.700264271802365 and y-coord 0.654116363179049
#
# on element 137 node-2 has global number 79
# node-2 has x-coord 0.7516124797967334 and y-coord 0.5701303236396061
#
# on element 137 node-3 has global number 83
# node-3 has x-coord 0.8000000000003898 and y-coord 0.6535898384882728
#
# on element 138 node-1 has global number 81
# node-1 has x-coord 0.7535358109397505 and y-coord 0.398725467089393
#
# on element 138 node-2 has global number 73
# node-2 has x-coord 0.6507352432846287 and y-coord 0.3943325211712257
#
# on element 138 node-3 has global number 82
# node-3 has x-coord 0.7000000000012385 and y-coord 0.3071796769756584
#
# on element 139 node-1 has global number 75
# node-1 has x-coord 0.4001075906650136 and y-coord 0.3073017552560426
#
# on element 139 node-2 has global number 76
# node-2 has x-coord 0.3000000000029347 and y-coord 0.3071796769753509
#
# on element 139 node-3 has global number 110
# node-3 has x-coord 0.3492006954957157 and y-coord 0.2288327370242559
#
# on element 140 node-1 has global number 55
# node-1 has x-coord 0.1504237369277891 and y-coord 0.08467720450543256
#
# on element 140 node-2 has global number 6
# node-2 has x-coord 0.1999999999995579 and y-coord 0.0
#
# on element 140 node-3 has global number 105
# node-3 has x-coord 0.2471893802660856 and y-coord 0.08407329706072986
#
# on element 141 node-1 has global number 73
# node-1 has x-coord 0.6507352432846287 and y-coord 0.3943325211712257
#
# on element 141 node-2 has global number 67
# node-2 has x-coord 0.5999572411359403 and y-coord 0.4804104109524933
#
# on element 141 node-3 has global number 111
# node-3 has x-coord 0.5500650581848795 and y-coord 0.3939126281557884
#
# on element 142 node-1 has global number 86
# node-1 has x-coord 0.8109810542586341 and y-coord 0.3047536098154713
#
# on element 142 node-2 has global number 82
# node-2 has x-coord 0.7000000000012385 and y-coord 0.3071796769756584
#
# on element 142 node-3 has global number 87
# node-3 has x-coord 0.7487737367126555 and y-coord 0.2215627586077865
#
# on element 143 node-1 has global number 25
# node-1 has x-coord 0.7000000000006934 and y-coord 1.0
#
# on element 143 node-2 has global number 45
# node-2 has x-coord 0.6500000000008002 and y-coord 0.9133974596219514
#
# on element 143 node-3 has global number 109
# node-3 has x-coord 0.7499293771789075 and y-coord 0.9137183489341748
#
# on element 144 node-1 has global number 75
# node-1 has x-coord 0.4001075906650136 and y-coord 0.3073017552560426
#
# on element 144 node-2 has global number 70
# node-2 has x-coord 0.3508014145113765 and y-coord 0.3944261231392702
#
# ...
# node-2 has x-coord 1.0 and y-coord 0.0
#
# on element 195 node-3 has global number 140
# node-3 has x-coord 0.9267949192432315 and y-coord 0.0732050807566482
#
# on element 196 node-1 has global number 1
# node-1 has x-coord 0.0 and y-coord 0.0
#
# on element 196 node-2 has global number 5
# node-2 has x-coord 0.09999999999981467 and y-coord 0.0
#
# on element 196 node-3 has global number 141
# node-3 has x-coord 0.07320508075662228 and y-coord 0.0732050807567834
#
# on element 197 node-1 has global number 40
# node-1 has x-coord 0.0 and y-coord 0.100000000000416
#
# on element 197 node-2 has global number 1
# node-2 has x-coord 0.0 and y-coord 0.0
#
# on element 197 node-3 has global number 141
# node-3 has x-coord 0.07320508075662228 and y-coord 0.0732050807567834
#
# on element 198 node-1 has global number 31
# node-1 has x-coord 0.100000000000416 and y-coord 1.0
#
# on element 198 node-2 has global number 4
# node-2 has x-coord 0.0 and y-coord 1.0
#
# on element 198 node-3 has global number 139
# node-3 has x-coord 0.07320508075687607 and y-coord 0.9267949192431241
#
# on element 199 node-1 has global number 37
# node-1 has x-coord 0.0 and y-coord 0.4000000000016644
#
# on element 199 node-2 has global number 38
# node-2 has x-coord 0.0 and y-coord 0.3000000000012483
#
# on element 199 node-3 has global number 125
# node-3 has x-coord 0.07972803913531296 and y-coord 0.3493512757062616
#
# on element 200 node-1 has global number 56
# node-1 has x-coord 0.9170502595852441 and y-coord 0.150593231699023
#
# on element 200 node-2 has global number 107
# node-2 has x-coord 0.9132469817449557 and y-coord 0.250891140252
#
# on element 200 node-3 has global number 126
# node-3 has x-coord 0.8380531170040474 and y-coord 0.1999999999995608
#
# on element 201 node-1 has global number 122
# node-1 has x-coord 0.189057567046849 and y-coord 0.2940842362157939
#
# on element 201 node-2 has global number 106
# node-2 has x-coord 0.1856343100128922 and y-coord 0.1794039491425674
#
# on element 201 node-3 has global number 137
# node-3 has x-coord 0.2613872612265493 and y-coord 0.2359890604552144
#
# on element 202 node-1 has global number 47
# node-1 has x-coord 0.9133974596218086 and y-coord 0.3499999999991206
#
# on element 202 node-2 has global number 101
# node-2 has x-coord 0.9157740970141776 and y-coord 0.4494733817703521
#
# on element 202 node-3 has global number 127
# node-3 has x-coord 0.8406928938275637 and y-coord 0.3992789991981978
#
# on element 203 node-1 has global number 110
# node-1 has x-coord 0.3492006954957157 and y-coord 0.2288327370242559
#
# on element 203 node-2 has global number 76
# node-2 has x-coord 0.3000000000029347 and y-coord 0.3071796769753509
#
# on element 203 node-3 has global number 137
# node-3 has x-coord 0.2613872612265493 and y-coord 0.2359890604552144
#
# on element 204 node-1 has global number 79
# node-1 has x-coord 0.7516124797967334 and y-coord 0.5701303236396061
#
# on element 204 node-2 has global number 102
# node-2 has x-coord 0.8167956118738324 and y-coord 0.4899817334731326
#
# on element 204 node-3 has global number 136
# node-3 has x-coord 0.8366096411895954 and y-coord 0.5826881150315605
#
# on element 205 node-1 has global number 106
# node-1 has x-coord 0.1856343100128922 and y-coord 0.1794039491425674
#
# on element 205 node-2 has global number 105
# node-2 has x-coord 0.2471893802660856 and y-coord 0.08407329706072986
#
# on element 205 node-3 has global number 128
# node-3 has x-coord 0.2898261153518074 and y-coord 0.1633999302292045
#
# on element 206 node-1 has global number 83
# node-1 has x-coord 0.8000000000003898 and y-coord 0.6535898384882728
#
# on element 206 node-2 has global number 79
# node-2 has x-coord 0.7516124797967334 and y-coord 0.5701303236396061
#
# on element 206 node-3 has global number 136
# node-3 has x-coord 0.8366096411895954 and y-coord 0.5826881150315605
#
# on element 207 node-1 has global number 130
# node-1 has x-coord 0.6999999999992162 and y-coord 0.1535898384871374
#
# on element 207 node-2 has global number 116
# node-2 has x-coord 0.650000000001663 and y-coord 0.2205771365975231
#
# on element 207 node-3 has global number 131
# node-3 has x-coord 0.5999999999988375 and y-coord 0.1535898384867511
#
# on element 208 node-1 has global number 48
# node-1 has x-coord 0.3475303635242556 and y-coord 0.08190748804974737
#
# on element 208 node-2 has global number 103
# node-2 has x-coord 0.4498499977837827 and y-coord 0.08393456559302379
#
# on element 208 node-3 has global number 133
# node-3 has x-coord 0.3977345286928267 and y-coord 0.1553736159967032
#
# on element 209 node-1 has global number 131
# node-1 has x-coord 0.5999999999988375 and y-coord 0.1535898384867511
#
# on element 209 node-2 has global number 85
# node-2 has x-coord 0.5500000000021426 and y-coord 0.2205771365975499
#
# on element 209 node-3 has global number 132
# node-3 has x-coord 0.4999999999989005 and y-coord 0.1535898384865979
#
# on element 210 node-1 has global number 85
# node-1 has x-coord 0.5500000000021426 and y-coord 0.2205771365975499
#
# on element 210 node-2 has global number 78
# node-2 has x-coord 0.4500000000024984 and y-coord 0.22057713659739
#
# on element 210 node-3 has global number 132
# node-3 has x-coord 0.4999999999989005 and y-coord 0.1535898384865979
#
# on element 211 node-1 has global number 116
# node-1 has x-coord 0.650000000001663 and y-coord 0.2205771365975231
#
# on element 211 node-2 has global number 85
# node-2 has x-coord 0.5500000000021426 and y-coord 0.2205771365975499
#
# on element 211 node-3 has global number 131
# node-3 has x-coord 0.5999999999988375 and y-coord 0.1535898384867511
#
# on element 212 node-1 has global number 33
# node-1 has x-coord 0.0 and y-coord 0.7999999999999998
#
# on element 212 node-2 has global number 34
# node-2 has x-coord 0.0 and y-coord 0.7000000000006934
#
# on element 212 node-3 has global number 129
# node-3 has x-coord 0.06578358757521621 and y-coord 0.7469795572487384
#
# on element 213 node-1 has global number 87
# node-1 has x-coord 0.7487737367126555 and y-coord 0.2215627586077865
#
# on element 213 node-2 has global number 116
# node-2 has x-coord 0.650000000001663 and y-coord 0.2205771365975231
#
# on element 213 node-3 has global number 130
# node-3 has x-coord 0.6999999999992162 and y-coord 0.1535898384871374
#
# on element 214 node-1 has global number 43
# node-1 has x-coord 0.5499999999988205 and y-coord 0.08660254037843171
#
# on element 214 node-2 has global number 100
# node-2 has x-coord 0.6499999999991333 and y-coord 0.08660254037864011
#
# on element 214 node-3 has global number 131
# node-3 has x-coord 0.5999999999988375 and y-coord 0.1535898384867511
#
# on element 215 node-1 has global number 100
# node-1 has x-coord 0.6499999999991333 and y-coord 0.08660254037864011
#
# on element 215 node-2 has global number 130
# node-2 has x-coord 0.6999999999992162 and y-coord 0.1535898384871374
#
# on element 215 node-3 has global number 131
# node-3 has x-coord 0.5999999999988375 and y-coord 0.1535898384867511
#
# on element 216 node-1 has global number 100
# node-1 has x-coord 0.6499999999991333 and y-coord 0.08660254037864011
#
# on element 216 node-2 has global number 51
# node-2 has x-coord 0.7459788032314767 and y-coord 0.07959225689678907
#
# on element 216 node-3 has global number 130
# node-3 has x-coord 0.6999999999992162 and y-coord 0.1535898384871374
#
# on element 217 node-1 has global number 43
# node-1 has x-coord 0.5499999999988205 and y-coord 0.08660254037843171
#
# on element 217 node-2 has global number 131
# node-2 has x-coord 0.5999999999988375 and y-coord 0.1535898384867511
#
# on element 217 node-3 has global number 132
# node-3 has x-coord 0.4999999999989005 and y-coord 0.1535898384865979
#
# on element 218 node-1 has global number 103
# node-1 has x-coord 0.4498499977837827 and y-coord 0.08393456559302379
#
# on element 218 node-2 has global number 43
# node-2 has x-coord 0.5499999999988205 and y-coord 0.08660254037843171
#
# on element 218 node-3 has global number 132
# node-3 has x-coord 0.4999999999989005 and y-coord 0.1535898384865979
#
# on element 219 node-1 has global number 78
# node-1 has x-coord 0.4500000000024984 and y-coord 0.22057713659739
#
# on element 219 node-2 has global number 110
# node-2 has x-coord 0.3492006954957157 and y-coord 0.2288327370242559
#
# on element 219 node-3 has global number 133
# node-3 has x-coord 0.3977345286928267 and y-coord 0.1553736159967032
#
# on element 220 node-1 has global number 132
# node-1 has x-coord 0.4999999999989005 and y-coord 0.1535898384865979
#
# on element 220 node-2 has global number 78
# node-2 has x-coord 0.4500000000024984 and y-coord 0.22057713659739
#
# on element 220 node-3 has global number 133
# node-3 has x-coord 0.3977345286928267 and y-coord 0.1553736159967032
#
# on element 221 node-1 has global number 103
# node-1 has x-coord 0.4498499977837827 and y-coord 0.08393456559302379
#
# on element 221 node-2 has global number 132
# node-2 has x-coord 0.4999999999989005 and y-coord 0.1535898384865979
#
# on element 221 node-3 has global number 133
# node-3 has x-coord 0.3977345286928267 and y-coord 0.1553736159967032
#
# on element 222 node-1 has global number 84
# node-1 has x-coord 0.747143410205979 and y-coord 0.7386054505286098
#
# on element 222 node-2 has global number 83
# node-2 has x-coord 0.8000000000003898 and y-coord 0.6535898384882728
#
# on element 222 node-3 has global number 134
# node-3 has x-coord 0.8325961894321569 and y-coord 0.7301442841501415
#
# on element 223 node-1 has global number 35
# node-1 has x-coord 0.0 and y-coord 0.6000000000013869
#
# on element 223 node-2 has global number 36
# node-2 has x-coord 0.0 and y-coord 0.5000000000020587
#
# on element 223 node-3 has global number 135
# node-3 has x-coord 0.0652562635316714 and y-coord 0.5500000000017228
#
# on element 224 node-1 has global number 102
# node-1 has x-coord 0.8167956118738324 and y-coord 0.4899817334731326
#
# on element 224 node-2 has global number 44
# node-2 has x-coord 0.9152217186777627 and y-coord 0.5468402906274978
#
# on element 224 node-3 has global number 136
# node-3 has x-coord 0.8366096411895954 and y-coord 0.5826881150315605
#
# on element 225 node-1 has global number 51
# node-1 has x-coord 0.7459788032314767 and y-coord 0.07959225689678907
#
# on element 225 node-2 has global number 123
# node-2 has x-coord 0.8440933898604552 and y-coord 0.09385434397709341
#
# on element 225 node-3 has global number 142
# node-3 has x-coord 0.7753798093615702 and y-coord 0.1497198395936735
#
# on element 226 node-1 has global number 119
# node-1 has x-coord 0.1530678781041703 and y-coord 0.9178724624824317
#
# on element 226 node-2 has global number 31
# node-2 has x-coord 0.100000000000416 and y-coord 1.0
#
# on element 226 node-3 has global number 139
# node-3 has x-coord 0.07320508075687607 and y-coord 0.9267949192431241
#
# on element 227 node-1 has global number 121
# node-1 has x-coord 0.08296629115975593 and y-coord 0.1498875452108657
#
# on element 227 node-2 has global number 40
# node-2 has x-coord 0.0 and y-coord 0.100000000000416
#
# on element 227 node-3 has global number 141
# node-3 has x-coord 0.07320508075662228 and y-coord 0.0732050807567834
#
# on element 228 node-1 has global number 120
# node-1 has x-coord 0.9167537064254057 and y-coord 0.8508718537559957
#
# on element 228 node-2 has global number 22
# node-2 has x-coord 1.0 and y-coord 0.8999999999997368
#
# on element 228 node-3 has global number 138
# node-3 has x-coord 0.926794919243098 and y-coord 0.926794919243139
#
# on element 229 node-1 has global number 123
# node-1 has x-coord 0.8440933898604552 and y-coord 0.09385434397709341
#
# on element 229 node-2 has global number 13
# node-2 has x-coord 0.8999999999997368 and y-coord 0.0
#
# on element 229 node-3 has global number 140
# node-3 has x-coord 0.9267949192432315 and y-coord 0.0732050807566482
#
# on element 230 node-1 has global number 23
# node-1 has x-coord 0.8999999999995836 and y-coord 1.0
#
# on element 230 node-2 has global number 54
# node-2 has x-coord 0.8495762630717529 and y-coord 0.9153227954948184
#
# on element 230 node-3 has global number 138
# node-3 has x-coord 0.926794919243098 and y-coord 0.926794919243139
#
# on element 231 node-1 has global number 32
# node-1 has x-coord 0.0 and y-coord 0.8999999999995836
#
# on element 231 node-2 has global number 53
# node-2 has x-coord 0.09056972474474832 and y-coord 0.8408174380938657
#
# on element 231 node-3 has global number 139
# node-3 has x-coord 0.07320508075687607 and y-coord 0.9267949192431241
#
# on element 232 node-1 has global number 14
# node-1 has x-coord 1.0 and y-coord 0.09999999999981467
#
# on element 232 node-2 has global number 56
# node-2 has x-coord 0.9170502595852441 and y-coord 0.150593231699023
#
# on element 232 node-3 has global number 140
# node-3 has x-coord 0.9267949192432315 and y-coord 0.0732050807566482
#
# on element 233 node-1 has global number 5
# node-1 has x-coord 0.09999999999981467 and y-coord 0.0
#
# on element 233 node-2 has global number 55
# node-2 has x-coord 0.1504237369277891 and y-coord 0.08467720450543256
#
# on element 233 node-3 has global number 141
# node-3 has x-coord 0.07320508075662228 and y-coord 0.0732050807567834
#
# on element 234 node-1 has global number 128
# node-1 has x-coord 0.2898261153518074 and y-coord 0.1633999302292045
#
# on element 234 node-2 has global number 110
# node-2 has x-coord 0.3492006954957157 and y-coord 0.2288327370242559
#
# on element 234 node-3 has global number 137
# node-3 has x-coord 0.2613872612265493 and y-coord 0.2359890604552144
#
# on element 235 node-1 has global number 53
# node-1 has x-coord 0.09056972474474832 and y-coord 0.8408174380938657
#
# on element 235 node-2 has global number 119
# node-2 has x-coord 0.1530678781041703 and y-coord 0.9178724624824317
#
# on element 235 node-3 has global number 139
# node-3 has x-coord 0.07320508075687607 and y-coord 0.9267949192431241
#
# on element 236 node-1 has global number 54
# node-1 has x-coord 0.8495762630717529 and y-coord 0.9153227954948184
#
# on element 236 node-2 has global number 120
# node-2 has x-coord 0.9167537064254057 and y-coord 0.8508718537559957
#
# on element 236 node-3 has global number 138
# node-3 has x-coord 0.926794919243098 and y-coord 0.926794919243139
#
# on element 237 node-1 has global number 55
# node-1 has x-coord 0.1504237369277891 and y-coord 0.08467720450543256
#
# on element 237 node-2 has global number 121
# node-2 has x-coord 0.08296629115975593 and y-coord 0.1498875452108657
#
# on element 237 node-3 has global number 141
# node-3 has x-coord 0.07320508075662228 and y-coord 0.0732050807567834
#
# on element 238 node-1 has global number 56
# node-1 has x-coord 0.9170502595852441 and y-coord 0.150593231699023
#
# on element 238 node-2 has global number 123
# node-2 has x-coord 0.8440933898604552 and y-coord 0.09385434397709341
#
# on element 238 node-3 has global number 140
# node-3 has x-coord 0.9267949192432315 and y-coord 0.0732050807566482
#
# on element 239 node-1 has global number 106
# node-1 has x-coord 0.1856343100128922 and y-coord 0.1794039491425674
#
# on element 239 node-2 has global number 128
# node-2 has x-coord 0.2898261153518074 and y-coord 0.1633999302292045
#
# on element 239 node-3 has global number 137
# node-3 has x-coord 0.2613872612265493 and y-coord 0.2359890604552144
#
# on element 240 node-1 has global number 126
# node-1 has x-coord 0.8380531170040474 and y-coord 0.1999999999995608
#
# on element 240 node-2 has global number 87
# node-2 has x-coord 0.7487737367126555 and y-coord 0.2215627586077865
#
# on element 240 node-3 has global number 142
# node-3 has x-coord 0.7753798093615702 and y-coord 0.1497198395936735
#
# on element 241 node-1 has global number 87
# node-1 has x-coord 0.7487737367126555 and y-coord 0.2215627586077865
#
# on element 241 node-2 has global number 130
# node-2 has x-coord 0.6999999999992162 and y-coord 0.1535898384871374
#
# on element 241 node-3 has global number 142
# node-3 has x-coord 0.7753798093615702 and y-coord 0.1497198395936735
#
# on element 242 node-1 has global number 130
# node-1 has x-coord 0.6999999999992162 and y-coord 0.1535898384871374
#
# on element 242 node-2 has global number 51
# node-2 has x-coord 0.7459788032314767 and y-coord 0.07959225689678907
#
# on element 242 node-3 has global number 142
# node-3 has x-coord 0.7753798093615702 and y-coord 0.1497198395936735
# false

# %%
# plot the nodes 
Plots.plot(xnode_coord,ynode_coord)

# %% [markdown]
# ## Section 3: Example: Inductor Geometry

# %% [markdown]
# Mesh generation for an inductor geometry.

# %%
#..1/5: initialize gmsh 
should_finalize = Gmsh.initialize()

#..2/5: generate geometry 
gmsh.option.setNumber("General.Terminal", 1)
#..define the model
model = gmsh.model
model.add("Inductor")
#..define mesh density near a point
lg = 0.7    #gap length in mm
lg = 5    #gap length in mm
mur = 2000;  #relative permeability of the core
mu0 = 4*pi*10^(-7);
curr_dens_value = 3.1085;
k = 0.2227
cl = 5     #mesh size at bounday
c2 = lg/2  #mesh size at airgap
c3 = 2     #mesh size at component
#..define four points in the geometry
gmsh.model.geo.addPoint(50, 50, 0., cl, 1)
gmsh.model.geo.addPoint(-50, 50, 0., cl, 2)
gmsh.model.geo.addPoint(-50, -50,0., cl, 3)
gmsh.model.geo.addPoint(50, -50, 0., cl, 4)
#..upper half of core
gmsh.model.geo.addPoint(-27.25, lg/2, 0., c2, 5)
gmsh.model.geo.addPoint(-27.25, 27.6+lg/2, 0., c3, 6)
gmsh.model.geo.addPoint(27.25, 27.6+lg/2, 0., c3, 7)
gmsh.model.geo.addPoint(27.25, lg/2, 0., c2, 8)
gmsh.model.geo.addPoint(20.6, lg/2, 0., c2, 9)
gmsh.model.geo.addPoint(20.6, 20.2+lg/2, 0., c3, 10)
gmsh.model.geo.addPoint(7.422, 20.2+lg/2, 0., c3, 11)
gmsh.model.geo.addPoint(7.422, lg/2, 0., c2, 12)
gmsh.model.geo.addPoint(-7.422, lg/2, 0., c2, 13)
gmsh.model.geo.addPoint(-7.422, 20.2+lg/2, 0., c3, 14)
gmsh.model.geo.addPoint(-20.6, 20.2+lg/2, 0., c3, 15)
gmsh.model.geo.addPoint(-20.6, lg/2, 0., c2, 16)
#..lower half of core
gmsh.model.geo.addPoint(-27.25, -lg/2, 0., c2, 17)
gmsh.model.geo.addPoint(-27.25, -27.6-lg/2, 0., c3, 18)
gmsh.model.geo.addPoint(27.25, -27.6-lg/2, 0., c3, 19)
gmsh.model.geo.addPoint(27.25, -lg/2, 0., c2, 20)
gmsh.model.geo.addPoint(20.6, -lg/2, 0., c2, 21)
gmsh.model.geo.addPoint(20.6, -20.2-lg/2, 0., c3, 22)
gmsh.model.geo.addPoint(7.422, -20.2-lg/2, 0., c3, 23)
gmsh.model.geo.addPoint(7.422, -lg/2, 0., c2, 24)
gmsh.model.geo.addPoint(-7.422, -lg/2, 0., c2, 25)
gmsh.model.geo.addPoint(-7.422, -20.2-lg/2, 0., c3, 26)
gmsh.model.geo.addPoint(-20.6, -20.2-lg/2, 0., c3, 27)
gmsh.model.geo.addPoint(-20.6, -lg/2, 0., c2, 28)
#..define four edges in the geometry
gmsh.model.geo.addLine(1, 2, 101)
gmsh.model.geo.addLine(2, 3, 102)
gmsh.model.geo.addLine(3, 4, 103)
gmsh.model.geo.addLine(4, 1, 104)
#..upper half of core
gmsh.model.geo.addLine(5, 6, 105)
gmsh.model.geo.addLine(6, 7, 106)
gmsh.model.geo.addLine(7, 8, 107)
gmsh.model.geo.addLine(8, 9, 108)
gmsh.model.geo.addLine(9, 10, 109)
gmsh.model.geo.addLine(10, 11, 110)
gmsh.model.geo.addLine(11, 12, 111)
gmsh.model.geo.addLine(12, 13, 112)
gmsh.model.geo.addLine(13, 14, 113)
gmsh.model.geo.addLine(14, 15, 114)
gmsh.model.geo.addLine(15, 16, 115)
gmsh.model.geo.addLine(16, 5, 116)
#..lower half of core
gmsh.model.geo.addLine(18, 17, 117)
gmsh.model.geo.addLine(19, 18, 118)
gmsh.model.geo.addLine(20, 19, 119)
gmsh.model.geo.addLine(21, 20, 120)
gmsh.model.geo.addLine(22, 21, 121)
gmsh.model.geo.addLine(23, 22, 122)
gmsh.model.geo.addLine(24, 23, 123)
gmsh.model.geo.addLine(25, 24, 124)
gmsh.model.geo.addLine(26, 25, 125)
gmsh.model.geo.addLine(27, 26, 126)
gmsh.model.geo.addLine(28, 27, 127)
gmsh.model.geo.addLine(17, 28, 128)
# close off winding slots (right to left)
gmsh.model.geo.addLine(21, 9, 129)
gmsh.model.geo.addLine(12, 24, 130)
gmsh.model.geo.addLine(25, 13, 131)
gmsh.model.geo.addLine(16, 28, 132)
# link core area to outside
gmsh.model.geo.addLine(2, 6, 133)
gmsh.model.geo.addLine(19, 4, 134)
gmsh.model.geo.addLine(9, 21, 135)
gmsh.model.geo.addLine(6, 2, 136)
gmsh.model.geo.addLine(4, 19, 137)
gmsh.model.geo.addLine(28,16, 138)
# redefine air gap lines for middle gap
gmsh.model.geo.addLine(24, 12, 139)
gmsh.model.geo.addLine(13, 25, 140)
#..define outer boundary
gmsh.model.geo.addCurveLoop([101, 133, 106, 107, 108, 135, 120, 119, 134, 104], 201) # air 1
gmsh.model.geo.addCurveLoop([102, 103, 137, 118, 117, 128, 138, 116, 105, 136], 202) # air 2
gmsh.model.geo.addCurveLoop([105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116], 203) # upper core
gmsh.model.geo.addCurveLoop([117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128], 204) # lower core
gmsh.model.geo.addCurveLoop([109, 110, 111, 130, 123, 122 , 121, 129], 205) # right winding gap
gmsh.model.geo.addCurveLoop([113, 114, 115, 131, 125, 126 ,127, 132], 206) # left winding gap
gmsh.model.geo.addCurveLoop([112, 140, 124, 139], 207) # middle air gap
#..define planar surface
gmsh.model.geo.addPlaneSurface([201], 301)
gmsh.model.geo.addPlaneSurface([202], 302)
gmsh.model.geo.addPlaneSurface([203], 303)
gmsh.model.geo.addPlaneSurface([204], 304)
gmsh.model.geo.addPlaneSurface([205], 305)
gmsh.model.geo.addPlaneSurface([206], 306)
gmsh.model.geo.addPlaneSurface([207], 307)
#..define physics
gmsh.model.addPhysicalGroup(2,[301; 302; 307],401)
gmsh.model.addPhysicalGroup(2,[303],402)
gmsh.model.addPhysicalGroup(2,[304],403)
gmsh.model.addPhysicalGroup(2,[305],404)
gmsh.model.addPhysicalGroup(2,[306],405)
#..synchronize the model 
gmsh.model.geo.synchronize()

#..3/5: generate two-dimensional mesh
model.mesh.generate(2)

#..4/5: write mesh to mesh and visualize the mesh  
#..if true, write mesh to file for further processing 
if (true) gmsh.write("data/inductor.msh") end 
#..if true, visualize mesh through the GUI 
if (false) gmsh.fltk.run() end 

#..5/5: finalize gmsh 
should_finalize && Gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 101 (Line)
# Info    : [ 10%] Meshing curve 102 (Line)
# Info    : [ 10%] Meshing curve 103 (Line)
# Info    : [ 10%] Meshing curve 104 (Line)
# Info    : [ 20%] Meshing curve 105 (Line)
# Info    : [ 20%] Meshing curve 106 (Line)
# Info    : [ 20%] Meshing curve 107 (Line)
# Info    : [ 20%] Meshing curve 108 (Line)
# Info    : [ 30%] Meshing curve 109 (Line)
# Info    : [ 30%] Meshing curve 110 (Line)
# Info    : [ 30%] Meshing curve 111 (Line)
# Info    : [ 30%] Meshing curve 112 (Line)
# Info    : [ 40%] Meshing curve 113 (Line)
# Info    : [ 40%] Meshing curve 114 (Line)
# Info    : [ 40%] Meshing curve 115 (Line)
# Info    : [ 40%] Meshing curve 116 (Line)
# Info    : [ 50%] Meshing curve 117 (Line)
# Info    : [ 50%] Meshing curve 118 (Line)
# Info    : [ 50%] Meshing curve 119 (Line)
# Info    : [ 50%] Meshing curve 120 (Line)
# Info    : [ 60%] Meshing curve 121 (Line)
# Info    : [ 60%] Meshing curve 122 (Line)
# Info    : [ 60%] Meshing curve 123 (Line)
# Info    : [ 60%] Meshing curve 124 (Line)
# Info    : [ 70%] Meshing curve 125 (Line)
# Info    : [ 70%] Meshing curve 126 (Line)
# Info    : [ 70%] Meshing curve 127 (Line)
# Info    : [ 70%] Meshing curve 128 (Line)
# Info    : [ 80%] Meshing curve 129 (Line)
# Info    : [ 80%] Meshing curve 130 (Line)
# Info    : [ 80%] Meshing curve 131 (Line)
# Info    : [ 80%] Meshing curve 132 (Line)
# Info    : [ 90%] Meshing curve 133 (Line)
# Info    : [ 90%] Meshing curve 134 (Line)
# Info    : [ 90%] Meshing curve 135 (Line)
# Info    : [ 90%] Meshing curve 136 (Line)
# Info    : [100%] Meshing curve 137 (Line)
# Info    : [100%] Meshing curve 138 (Line)
# Info    : [100%] Meshing curve 139 (Line)
# Info    : [100%] Meshing curve 140 (Line)
# Info    : Done meshing 1D (Wall 0.00379325s, CPU 0.00373s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 301 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 302 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 303 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 304 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 305 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 306 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 307 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.019016s, CPU 0.018845s)
# Info    : 1832 nodes 3942 elements
# Info    : Writing 'data/inductor.msh'...
# Info    : Done writing 'data/inductor.msh'
# Warning : Unknown entity of dimension 2 and tag 301 in physical group 401
# Warning : Unknown entity of dimension 2 and tag 302 in physical group 401
# Warning : Unknown entity of dimension 2 and tag 307 in physical group 401
# Warning : Unknown entity of dimension 2 and tag 303 in physical group 402
# Warning : Unknown entity of dimension 2 and tag 304 in physical group 403
# Warning : Unknown entity of dimension 2 and tag 305 in physical group 404
# Warning : Unknown entity of dimension 2 and tag 306 in physical group 405
# false
