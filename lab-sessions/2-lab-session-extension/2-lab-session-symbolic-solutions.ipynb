# %% [markdown]
# # Analytical and Symbolic Computations
#
# This notebook should be run in the Python kernel as parts employs sympy.

# %% [markdown]
# ## Import Package

# %% [markdown]
# ## Section 1: Analytical Reference Solution

# %%
from sympy import Function, dsolve, Derivative, Eq, sin, cos, symbols, pi, Lambda, Heaviside
from sympy.plotting import plot, PlotGrid
from sympy.abc import x

u, src = symbols("u src", cls=Function)
x      = symbols("x")
src    = Lambda(x, -x*(x-1))

# Solve the ODE ()
eqn  = Eq(Derivative(u(x), x, x) + src(x),0)
ics0 = {u(0): 0, u(1): 0}

sol = dsolve(eqn,ics = ics0)

print(src)
print(sol)  

plotsrc = plot(src, (x, 0, 1), show=False)
plotu   = plot(sol.rhs, (x, 0, 1), show=False)
plotdu  = plot(Derivative(sol.rhs,x,evaluate=True), (x, 0, 1), show=False)
PlotGrid(1,3,plotsrc, plotu, plotdu)
# Out:
# Lambda(x, -x*(x - 1))
# Eq(u(x), x**4/12 - x**3/6 + x/12)

# %%
Derivative(sol.rhs,x,evaluate=True)
# Out:
# x**3/3 - x**2/2 + 1/12

# %% [markdown]
# ## Section 2: Coil in Air

# %%
from sympy import Function, dsolve, Derivative, Eq, sin, cos, symbols, pi, Lambda, Heaviside
from sympy.plotting import plot, PlotGrid
from sympy.abc import x

u, src = symbols("u src", cls=Function)
x      = symbols("x")
src    = Lambda(x, (Heaviside(x-0.35) - Heaviside(x-0.45)) - (Heaviside(x-0.55) - Heaviside(x-0.65)))
Iamp   = symbols("Iamp", positive=True)

# Solve the ODE ()
eqn  = Eq(Derivative(u(x), x, x) + src(x),0)
ics0 = {u(0): 0, u(1): 0}

sol = dsolve(eqn,ics = ics0)

print(src)
print(sol)  

plotsrc = plot(src, (x, 0, 1), show=False)
plotu   = plot(sol.rhs, (x, 0, 1), show=False)
plotdu  = plot(Derivative(sol.rhs,x,evaluate=True), (x, 0, 1), show=False)
PlotGrid(1,3,plotsrc, plotu, plotdu)
# Out:
# Lambda(x, Heaviside(x - 0.65) - Heaviside(x - 0.55) - Heaviside(x - 0.45) + Heaviside(x - 0.35))
# Eq(u(x), x**2*(Heaviside(x - 0.65) - Heaviside(x - 0.55) - Heaviside(x - 0.45) + Heaviside(x - 0.35))/2 + x*(-Piecewise((0, 1.53846153846154*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 1.53846153846154*x), True)) + Piecewise((0, 1.81818181818182*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 1.81818181818182*x), True)) + Piecewise((0, 2.22222222222222*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 2.22222222222222*x), True)) - Piecewise((0, 2.85714285714286*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 2.85714285714286*x), True)) + 0.02) - 0.21125*Heaviside(x - 0.65) + 0.15125*Heaviside(x - 0.55) + 0.10125*Heaviside(x - 0.45) - 0.06125*Heaviside(x - 0.35))
# /opt/anaconda3/lib/python3.12/site-packages/sympy/plotting/series.py:73: UserWarning: The evaluation with NumPy/SciPy failed.
# NameError: name 'DiracDelta' is not defined
# Trying to evaluate the expression with Sympy, but it might be a slow operation.
#   warnings.warn(

# %%
Derivative(sol.rhs,x,evaluate=True)
# Out:
# x**2*(DiracDelta(x - 0.65) - DiracDelta(x - 0.55) - DiracDelta(x - 0.45) + DiracDelta(x - 0.35))/2 + x*(-Piecewise((0, 1.53846153846154*Abs(x) < 1), (1.0*meijerg(((-1, 1), ()), ((), (-1, 0)), 1.53846153846154*x), True)) + Piecewise((0, 1.81818181818182*Abs(x) < 1), (1.0*meijerg(((-1, 1), ()), ((), (-1, 0)), 1.81818181818182*x), True)) + Piecewise((0, 2.22222222222222*Abs(x) < 1), (1.0*meijerg(((-1, 1), ()), ((), (-1, 0)), 2.22222222222222*x), True)) - Piecewise((0, 2.85714285714286*Abs(x) < 1), (1.0*meijerg(((-1, 1), ()), ((), (-1, 0)), 2.85714285714286*x), True))) + x*(Heaviside(x - 0.65) - Heaviside(x - 0.55) - Heaviside(x - 0.45) + Heaviside(x - 0.35)) - Piecewise((0, 1.53846153846154*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 1.53846153846154*x), True)) + Piecewise((0, 1.81818181818182*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 1.81818181818182*x), True)) + Piecewise((0, 2.22222222222222*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 2.22222222222222*x), True)) - Piecewise((0, 2.85714285714286*Abs(x) < 1), (x*meijerg(((0, 1), ()), ((), (-1, 0)), 2.85714285714286*x), True)) - 0.21125*DiracDelta(x - 0.65) + 0.15125*DiracDelta(x - 0.55) + 0.10125*DiracDelta(x - 0.45) - 0.06125*DiracDelta(x - 0.35) + 0.02
